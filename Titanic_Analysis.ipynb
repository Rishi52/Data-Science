# %%
import seaborn as sns
import matplotlib.pyplot as plt 
df=sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %% [markdown]
# ## 1 Which gender were most on ship

# %%
sns.histplot(data=df,x='sex')
# Out:
# <Axes: xlabel='sex', ylabel='Count'>

# %%
df['sex'].value_counts()
# Out:
# sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
sns.countplot(data=df,x='sex')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# ## 2 Which passenger class has less no of passengers

# %%
plt.figure(figsize=(10,4))
sns.countplot(data=df,x='class',hue='survived')
plt.show()

# %% [markdown]
# ## 3 Was no of passengers who survived greater or less than no of passengers who   survived

# %%
sns.countplot(data=df,x='survived')
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %% [markdown]
# ## 4 From which town most passengers embarked

# %%
sns.countplot(data=df,x='embark_town')
# Out:
# <Axes: xlabel='embark_town', ylabel='count'>

# %% [markdown]
# ## 5 how does the survival rate differ b/w M/F

# %%
sns.countplot(data=df,x='sex',hue='survived')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# ## 6 Which class passengers NOT survived more in num

# %%
sns.countplot(data=df,x='survived',hue='class')
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %% [markdown]
# ## 7 Which town embarked passengers survived least in number

# %%
sns.countplot(data=df,x='embark_town',hue='survived')
# Out:
# <Axes: xlabel='embark_town', ylabel='count'>

# %% [markdown]
# ## 8 Average fare was high for which gender

# %%
sns.barplot(data=df,x='sex',y='fare')
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %% [markdown]
# ## 9 Explore the relationship between fare and survival Do passengers who paid higher fares have better chance of surviaval

# %%
plt.figure(figsize=(10,4))
sns.barplot(data=df,x='survived',y='fare')
# Out:
# <Axes: xlabel='survived', ylabel='fare'>

# %% [markdown]
# ## 10 Investigate the relationship b/w age and survival Are younger passengers more likely to survieved

# %%
sns.barplot(data=df,x='survived',y='age')
# Out:
# <Axes: xlabel='survived', ylabel='age'>

# %%
sns.pointplot(data=df,x='survived',y='age')
# Out:
# <Axes: xlabel='survived', ylabel='age'>

# %%
sns.boxplot(data=df,x='survived',y='age')
# Out:
# <Axes: xlabel='survived', ylabel='age'>

# %%
# Bar plot
sns.countplot(x='survived', data=df)
plt.xlabel('Survival Status')
plt.ylabel('Count')
plt.title('Survival Count')
plt.show()

# %%
# Histogram
plt.hist(df['age'], bins=10)
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Distribution of Age')
plt.show()

# %%
# Scatter plot
plt.scatter(df['age'], df['fare'])
plt.xlabel('Age')
plt.ylabel('Fare')
plt.title('Age vs. Fare')
plt.show()

# %%
# Box plot
sns.boxplot(x=df['survived'], y=df['fare'])
plt.xlabel('Survival Status')
plt.ylabel('Fare')
plt.title('Survival Status vs. Fare')
plt.show()
